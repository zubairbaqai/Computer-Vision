# %% [markdown]
# ## 1) Importing All Modules

# %%
import numpy as np
from scipy.linalg import svd
from numpy.linalg import matrix_rank
import cv2 as cv
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20, 20 ### Setting the Fixed Size of thr Windows

# %% [markdown]
# ### A kernel is seperable if rank of the filter is 1 (outer product of 2 vectors) . that is we can convert a 2-dimensional filter to 2 seperate 1-dimensional filter . lets prove this by following , we know that Sobel, Average and Gaussian Filters are Seperable so lets check their ranks first

# %% [markdown]
# ### Checking the Rank of Sobel Operator , we see we get rank 1 , which means its seperable

# %%
SobelOperator = np.array([[-1,0,1], [-2, 0, 2], [-1, 0, 1]])
print(matrix_rank(SobelOperator))
# Out:
# 1

# %% [markdown]
# ### Check the Rank of Averaging Filter , which we see is also 1  , and we know Averaging filter is seperable

# %%
Averaging =np.ones((5,5),np.float32)/25
print(matrix_rank(SobelOperator))
# Out:
# 1

# %% [markdown]
# ### Gaussian Filter Rank, which is seperable also get Rank 1

# %%
x, y = np.meshgrid(np.linspace(-1, 1, 500), np.linspace(-1, 1, 500)) ### We generate 500 number between -1 and 1, for both x and y 

print(x.shape)
print(y.shape)
gauss = np.exp(-5 * (x * x + y * y))

print(matrix_rank(gauss))
# Out:
# 1

# %% [markdown]
# ### 4) Cropping image using Slicing

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(image)
plt.title('Uncroppedimage')
plt.subplot(1,2,2)
CroppedImage = image[10:100,30:120,:]
plt.imshow(CroppedImage)
plt.title('CroppedImage')
plt.show()

# %% [markdown]
# ### 5) Geometric transformation (Applying Rescaling, Resizing and Rotation)

# %%
Rescaling = rescale(image,2,anti_aliasing=False,multichannel=True)
Resizing = resize(image,(image.shape[0] // 4, image.shape[1] // 4),anti_aliasing=True)
Rotation = rotate(image, 90,resize=True)


plt.subplot(2,2,1),plt.imshow(image,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(Rescaling,cmap = 'gray')
plt.title('Rescaling'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(Resizing,cmap = 'gray')
plt.title('Resizing'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(np.real(Rotation),cmap = 'gray')
plt.title('rotate'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# #### 6) Applying morphologies

# %%
orig_phantom = img_as_ubyte(data.shepp_logan_phantom())
plt.imshow(orig_phantom)
plt.title('ImageOn Which we apply morphologies')
plt.show()

selem = disk(6) 


###Morphological erosion sets a pixel at (i, j) to the minimum over all pixels in the neighborhood centered at (i, j)
eroded = erosion(orig_phantom, selem)


##Morphological dilation sets a pixel at (i, j) to the maximum over all pixels in the neighborhood centered at (i, j). Dilation enlarges bright regions and shrinks dark regions.
dilated = dilation(orig_phantom, selem)


#Morphological opening on an image is defined as an erosion followed by a dilation. Opening can remove small bright spots (i.e. “salt”) and connect small dark cracks.
opened = opening(orig_phantom, selem)


#Morphological closing on an image is defined as a dilation followed by an erosion. Closing can remove small dark spots (i.e. “pepper”) and connect small bright cracks. To illustrate this more clearly, let’s add a small crack to the white border:
phantom = orig_phantom.copy()
phantom[10:30, 200:210] = 0

closed = closing(phantom, selem)

# %%
plt.subplot(2,2,1),plt.imshow(closed,cmap = 'gray')
plt.title('closed'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(eroded,cmap = 'gray')
plt.title('eroded'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(dilated,cmap = 'gray')
plt.title('dilated'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(np.real(opened),cmap = 'gray')
plt.title('opened'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# #### 7) Experimenting RegionProps

# %%
coins_image = data.coins()


thres = threshold_otsu(coins_image) ## We find The OTSU threshold for the coin image
closingFunc = closing(coins_image > thres,square(5))
clearborder = clear_border(closingFunc)
blurred = gaussian(clearborder, sigma=5)




binary = blurred > threshold_otsu(blurred)
labels = measure.label(binary)

plots = {'Original': coins_image, 'Blurred': blurred, 
         'Binary': binary, 'Labels': labels}
fig, ax = plt.subplots(1, len(plots))
for n, (title, img) in enumerate(plots.items()):
    cmap = plt.cm.gnuplot if n == len(plots) - 1 else plt.cm.gray
    ax[n].imshow(img, cmap=cmap)
    ax[n].axis('off')
    ax[n].set_title(title)
plt.show(fig)

# %% [markdown]
# ### 8) Choosing only large Coins, and drawing rectangles on it

# %%
figure,axes = plt.subplots(figsize=(15,15))
image_label_overlay = label2rgb(labels,coins_image,bg_label=0)

axes.imshow(image_label_overlay)


props = measure.regionprops(labels)
for regions in props:
    print('Label: {} >> Object size: {}'.format(regions.label, regions.area))
    if regions.area >=2500:
        min_r, min_c,max_r,max_c = regions.bbox
        rectangle = patches.Rectangle((min_c,min_r),max_c-min_c,max_r-min_r,
                                      fill = False,edgecolor='Green',linewidth=5)
        axes.add_patch(rectangle)

        
    elif regions.area >=1800:
        min_r, min_c,max_r,max_c = regions.bbox
        rectangle = patches.Rectangle((min_c,min_r),max_c-min_c,max_r-min_r,
                                      fill = False,edgecolor='blue',linewidth=5)
        axes.add_patch(rectangle)
        
plt.tight_layout()
plt.show()
# Out:
# Label: 1 >> Object size: 2648
# Label: 2 >> Object size: 1670
# Label: 3 >> Object size: 1243
# Label: 4 >> Object size: 1920
# Label: 5 >> Object size: 1335
# Label: 6 >> Object size: 1220
# Label: 7 >> Object size: 1183
# Label: 8 >> Object size: 1133
# Label: 9 >> Object size: 1105
# Label: 10 >> Object size: 3174
# Label: 11 >> Object size: 1751
# Label: 12 >> Object size: 1540
# Label: 13 >> Object size: 1490
# Label: 14 >> Object size: 1139
# Label: 15 >> Object size: 1161
# Label: 16 >> Object size: 2479
# Label: 17 >> Object size: 2314
# Label: 18 >> Object size: 2013
# Label: 19 >> Object size: 1783
# Label: 20 >> Object size: 1403
# Label: 21 >> Object size: 1485
